# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import copy

# %%
df = pd.read_csv('Stores.csv')
df
# Out:
#      Store ID   Store_Area  Items_Available  Daily_Customer_Count  Store_Sales
# 0            1        1659             1961                   530        66490
# 1            2        1461             1752                   210        39820
# 2            3        1340             1609                   720        54010
# 3            4        1451             1748                   620        53730
# 4            5        1770             2111                   450        46620
# ..         ...         ...              ...                   ...          ...
# 891        892        1582             1910                  1080        66390
# 892        893        1387             1663                   850        82080
# 893        894        1200             1436                  1060        76440
# 894        895        1299             1560                   770        96610
# 895        896        1174             1429                  1110        54340
#
# [896 rows x 5 columns]

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 896 entries, 0 to 895
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Store ID              896 non-null    int64
#  1   Store_Area            896 non-null    int64
#  2   Items_Available       896 non-null    int64
#  3   Daily_Customer_Count  896 non-null    int64
#  4   Store_Sales           896 non-null    int64
# dtypes: int64(5)
# memory usage: 35.1 KB
# (896, 5)

# %%
df.isnull().sum()
# Out:
# Store ID                0
# Store_Area              0
# Items_Available         0
# Daily_Customer_Count    0
# Store_Sales             0
# dtype: int64

# %%
df.describe().T
# Out:
#                       count          mean           std      min       25%  \
# Store ID              896.0    448.500000    258.797218      1.0    224.75
# Store_Area            896.0   1485.409598    250.237011    775.0   1316.75
# Items_Available       896.0   1782.035714    299.872053    932.0   1575.50
# Daily_Customer_Count  896.0    786.350446    265.389281     10.0    600.00
# Store_Sales           896.0  59351.305804  17190.741895  14920.0  46530.00
#
#                           50%       75%       max
# Store ID                448.5    672.25     896.0
# Store_Area             1477.0   1653.50    2229.0
# Items_Available        1773.5   1982.75    2667.0
# Daily_Customer_Count    780.0    970.00    1560.0
# Store_Sales           58605.0  71872.50  116320.0

# %%
plt.figure(figsize= (20,15))
plt.subplot(3,1,1)
sns.boxplot(x= df.Store_Sales, color='lightblue')
# Out:
# <AxesSubplot:xlabel='Store_Sales'>

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(20,20))
# sns.scatterplot(df.Store_Area, df.Store_Sales ,alpha=0.6)
sns.scatterplot(df.Store_Area, df.Items_Available,hue=df.Store_Sales, palette='rainbow' ,alpha=0.6)
plt.title("Difference between charges of smokers and charges of non-smokers is apparent")
plt.show()
# Out:
# D:\Programming\New folder (2)\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# this plot show as the store area increase the available items icrease as well and that is normal to fill the store capacity 


# regarding the store sales doesn't seem to change much depending on these

# we can tell that the grdient on the right slightly showes more sales but it's not a major thing to consider

# %%
plt.figure(figsize=(25,20))

plt.subplot(4,1,1)
a = df.groupby('Store_Area')['Daily_Customer_Count'].mean()
plt.plot(a, color='black')
plt.title('Average customer count per soter area Trend')
plt.xlabel('Store_Area')
plt.ylabel('Daily_Customer_Count')



plt.subplot(4,1,2)
a = df.groupby('Store_Area')['Store_Sales'].mean()
plt.plot(a, color='black')
plt.title('Average store salesper Area  Trend')
plt.xlabel('Store_Area')
plt.ylabel('Store_Sales')



plt.subplot(4,1,3)
a = df.groupby('Store_Area')['Items_Available'].mean()
plt.plot(a, color='black')
plt.title('Average Items Available  Trend')
plt.xlabel('Store_Area')
plt.ylabel('Items_Available')




plt.subplot(4,1,4)
a = df.groupby('Items_Available')['Store_Sales'].mean()
plt.plot(a, color='black')
plt.title('Average Items Available to sales  Trend')
plt.xlabel('Items_Available')
plt.ylabel('Store_Sales')
# Out:
# Text(0, 0.5, 'Store_Sales')

# %%
# from these trends we can get that increasing the store size is not affecting the sales or the number of customers in the store

# %%
sns.jointplot(x='Store_Area',y='Store_Sales',data=df,kind='reg')

# %%
sns.jointplot(x='Daily_Customer_Count',y='Store_Sales',data=df,kind='reg')

# %%
sns.jointplot(x='Items_Available',y='Store_Sales',data=df,kind='reg')

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),cmap='coolwarm',annot=True)
# Out:
# <AxesSubplot:>

# %%
# everything seems to be normally ditributed but we can see a high corelation between store location and items available

# %%
# this can be an indication that these stores keep the same quality and performance or we may require more data or another variable to consider between the stores
